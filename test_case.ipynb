# %% [markdown]
# # test 1.

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))
    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    print("////////")
    #### 1投4(救人) ####
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=2 , chat="save" , room_name=room_name , stage_name="1-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=-1 , chat="save" , room_name=room_name , stage_name="1-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=6 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false

    #### 第一天發言 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-witch"))

    for i in range(7):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        # print(sendUserOperation(stub , user=5 , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 0,1,2,3,4,5,6 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))

    #### 0,1,2,3投6 4,5,6投3 ####
    for i in range(7):
        target = 1 
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-vote1"))

    #### 第一天二次投票 ####
    #### 0投6 ####

    ####################

    #### 第一天6獵人死掉發言及發動技能 ####
    #### 0,1,2,3,4,5 存活 ####
    # #### !!!! Error 先發言就不能發動技能 反之亦然  ####
    # print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=4 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    # print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=7 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    # print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    # print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=4 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    # print(sendUserOperation(stub , user=6 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="1-1-hunter2"))
    # ####################

    #### 第一天4被獵人殺掉發言 ####
    #### 0,1,2,3,5 存活 ####
    # print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    
    print("/////////////////////")

    #### 第二天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    #### 5投0 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=0 , chat="" , room_name=room_name , stage_name="2-0-werewolf"))

    #### 第二天預言家驗人 ####

    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-werewolf"))
    ####################

    #### 第二天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-seer"))
    #### 第二天公告誰死了 ####
    #### 1,2,3,5 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-witch"))
    #### 第二天發言 ####
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-check_end1"))
    for i in range(5):
        print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))

    #### 第二天投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    #### 0,1,2,3投6 4,5,6投3 ####
    for i in [2,3,4,5,6]:
        target = 4 if i<3 else 5
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="2-1-vote1"))
    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="2-1-vote1"))

    #### 第二天二次投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    #### 5投3 ####
    print("@@@")
    #### 第二天3死了發表遺言 ####
    #### 1,2,5 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=6, chat="" , room_name=room_name , stage_name="3-0-werewolf"))
    #print(sendUserOperation(stub , user=2 , operation="vote_or_not" , target=5 , chat="" , room_name=room_name , stage_name="2-1-vote2"))
    #### !!!! Error 程式跳錯 ####
    # print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="2-1-check_end3"))

    #### 第三天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-check_end3"))
    #### 5投1 ####

    #### 第三天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-werewolf"))
    #### 第三天女巫 ####
    #### !!!! Error 女巫stage沒回傳 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    #print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=5 , chat="poison" , room_name=room_name , stage_name="3-0-witch"))


if __name__ == '__main__':
    logging.basicConfig()
    run()
# Out:
# True
# False
# False
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 1
#
#   user : [1]
#   operation : vote_or_not
#   target : [4]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# ////////
# True
# False
# 1-1-check_end1
#   user : []
#   operation : other
#   target : []
#   description : 昨晚是平安夜
#
# 1-1-dialogue
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-vote1
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [0, 1, 2, 3, 4, 5, 6]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 投票階段
#
# True
# True
# True
# True
# True
# True
# True
# vote info :  [1, 1, 1, 1, 1, 1, 1]
# 1-1-check_end3
#   user : [1]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
# /////////////////////
# 2-0-werewolf
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [4, 5]
#   operation : vote
#   target : [0, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# 2-0-seer
#   user : [0]
#   operation : vote
#   target : [2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# 2-0-witch
#   user : [0]
#   operation : role_info
#   target : [4]
#   description : 0
#
# 2-1-check_end1
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 2-1-dialogue
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-vote1
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [2, 3, 4, 5, 6]
#   operation : vote_or_not
#   target : [2, 3, 4, 5, 6]
#   description : 投票階段
#
# True
# True
# True
# True
# True
# vote info :  [-1, -1, 4, 5, 5, 5, 5]
# 2-1-check_end3
#   user : [5]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
# @@@
# 3-0-werewolf
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : vote
#   target : [2, 3, 4, 6]
#   description : 狼人投票殺人
#
# True
# 3-0-seer
#   user : [0]
#   operation : vote
#   target : []
#   description : 預言家查身分
#
# 3-0-witch
#   user : [1]
#   operation : vote_or_not
#   target : []
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : []
#   description : 女巫毒人
#
# 3-1-check_end1
#   user : [6]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [6]
#   operation : vote_or_not
#   target : [2, 3, 4]
#   description : 獵人殺人
#
#   user : []
#   operation : end
#   target : []
#   description : 遊戲結束 神職全死 壞人獲勝

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name))
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))

    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    #### 1投4(救人) ####
    #print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=4 , chat="save" , room_name=room_name , stage_name="1-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=0 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false

    ### 平安夜 ###
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-check_end1"))

    #### 第一天發言 ####

    for _ in range(5):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        for i in range(7): 
            print(sendUserOperation(stub , user=i , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 0,1,2,3,4,5,6 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))
    #### 0,1,2,3投6 4,5,6投3 ####
    for i in range(7):
        target = 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=6 , chat="" , room_name=room_name , stage_name="1-1-vote1"))


    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))

    ### 獵人stage
    #print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-hunter2"))
    
    #### 第一天6獵人死掉發言及發動技能 ####
    #### 0,1,2,3,4,5 存活 ####
    #print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=3 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    ####################

    #### 第一天4被獵人殺掉發言 ####
    #### 0,1,2,3,5 存活 ####
    #print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    #print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="1-1-check_end3"))
    #print("#")
    
    #### 第二天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    
    #### 5投0 ####

    #### 第二天預言家驗人 ####

    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=1 , chat="" , room_name=room_name , stage_name="2-0-werewolf"))
    ####################

    #### 第二天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-seer"))
    #### 第二天公告誰死了 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    #### 1,2,3,5 存活 ####
    
    #### 第二天發言 ####
    
    
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))

    
    #### 第二天投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print("$$")
    #### 1,2 投5 3,5投3 ####
    for i in [2,5,6]:
        target = 6 
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="2-1-vote1"))
    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="2-1-vote1"))

    #### 第二天二次投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))

    #### 5投3 ####
    #print(sendUserOperation(stub , user=5 , operation="vote_or_not" , target=3 , chat="" , room_name=room_name , stage_name="2-1-vote2"))

    #### 第二天3死了發表遺言 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="2-1-check_end3"))
    print("##")
    #### 1,2,5 存活 ####
    
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    #### 第三天狼人投票 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=1, chat="" , room_name=room_name , stage_name="3-0-werewolf"))
    #### 5投1 ####
    

    #### 第三天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-check_end3"))
    
    #### 第三天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-werewolf"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=5 , chat="poison" , room_name=room_name , stage_name="3-0-witch"))
    
    #### 遊戲結束 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

if __name__ == '__main__':
    logging.basicConfig()
    run()
# Out:
# True
# False
# False
# False
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 是好人
#
#   user : [1]
#   operation : vote_or_not
#   target : [4]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# 1-1-check_end1
#   user : [4]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# False
# False
# True
# False
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# False
# False
# False
# True
# 1-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# True
# False
# False
# False
# False
# False
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# True
# False
# False
# False
# False
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# True
# False
# False
# False
# 1-1-vote1
#   user : [3]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [1, 2, 3, 5, 6]
#   operation : vote_or_not
#   target : [1, 2, 3, 5, 6]
#   description : 投票階段
#
# False
# True
# True
# True
# False
# True
# True
# True
# True
# vote info :  [-1, 6, 3, 3, -1, 3, 3]
# 1-1-check_end3
#   user : [3]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
# 2-0-werewolf
#   user : [3]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [5]
#   operation : vote
#   target : [1, 2, 5, 6]
#   description : 狼人投票殺人
#
# True
# 2-0-seer
#   user : [0]
#   operation : vote
#   target : []
#   description : 預言家查身分
#
# 2-0-witch
#   user : [1]
#   operation : vote_or_not
#   target : [1]
#   description : 女巫救人
#
# 2-1-check_end1
#   user : [1]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 2-1-dialogue
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-vote1
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [2, 5, 6]
#   operation : vote_or_not
#   target : [2, 5, 6]
#   description : 投票階段
#
# $$
# True
# True
# True
# vote info :  [-1, -1, 6, -1, -1, 6, 6]
# 2-1-hunter2
#   user : [6]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : [6]
#   operation : vote_or_not
#   target : [2, 5]
#   description : 獵人殺人
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In[9], line 191
#     189 if __name__ == '__main__':
#     190     logging.basicConfig()
# --> 191     run()
#
# Cell In[9], line 168, in run()
#     162 print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
#     164 #### 5投3 ####
#     165 #print(sendUserOperation(stub , user=5 , operation="vote_or_not" , target=3 , chat="" , room_name=room_name , stage_name="2-1-vote2"))
#     166
#     167 #### 第二天3死了發表遺言 ####
# --> 168 print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
#     169 print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="2-1-check_end3"))
#     170 print("##")
#
# Cell In[9], line 20, in nextStage(stub, room_name, stage_name)
#      18 def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
#      19     room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
# ---> 20     stage_info = stub.nextStage(request=room_info)
#      21     return stage_info.stage ,stage_info.stage_name
#
# File c:\Users\yicheng\anaconda3\envs\gpu_env\lib\site-packages\grpc\_channel.py:1030, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1021 def __call__(self,
#    1022              request: Any,
#    1023              timeout: Optional[float] = None,
#    (...)
#    1026              wait_for_ready: Optional[bool] = None,
#    1027              compression: Optional[grpc.Compression] = None) -> Any:
#    1028     state, call, = self._blocking(request, timeout, metadata, credentials,
#    1029                                   wait_for_ready, compression)
# -> 1030     return _end_unary_response_blocking(state, call, False, None)
#
# File c:\Users\yicheng\anaconda3\envs\gpu_env\lib\site-packages\grpc\_channel.py:910, in _end_unary_response_blocking(state, call, with_call, deadline)
#     908         return state.response
#     909 else:
# --> 910     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "Exception calling application: 'TESTROOM'"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Exception calling application: \'TESTROOM\'", grpc_status:2, created_time:"2023-08-01T12:13:52.401702615+00:00"}"
# >

# %% [markdown]
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 1
#
#   user : [1]
#   operation : vote_or_not
#   target : [4]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# False
# 1-1-check_end1
#   user : []
#   operation : other
#   target : []
#   description : 昨晚平安夜
#
# 1-1-dialogue
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-vote1
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [0, 1, 2, 3, 4, 5, 6]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 投票階段
#
# True
# True
# True
# True
# True
# True
# True
# vote info :  [6, 6, 6, 6, 3, 3, 3]
# 1-1-hunter2
#   user : [6]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : [6]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5]
#   description : 獵人殺人
#
# True
# True
# 1-1-check_end3
#   user : [4]
#   operation : died
#   target : []
#   description : 被獵人帶走了
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
# 2-0-werewolf
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : vote
#   target : [0, 1, 2, 3, 5]
#   description : 狼人投票殺人
#
# True
# 2-0-seer
#   user : [0]
#   operation : vote
#   target : []
#   description : 預言家查身分
#
# 2-0-witch
#   user : [0]
#   operation : role_info
#   target : [5]
#   description : 0
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 女巫毒人
#
# 2-1-check_end1
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 2-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 2-1-vote1
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [1, 2, 3, 5]
#   operation : vote_or_not
#   target : [1, 2, 3, 5]
#   description : 投票階段
#
# True
# True
# True
# True
# vote info :  [-1, 5, 5, 3, -1, 3, -1]
# 2-1-vote2
#   user : [1, 2]
#   operation : vote_or_not
#   target : [5, 3]
#   description : 投票階段
#
# True
# 2-1-check_end3
#   user : [3]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
# True
# 3-0-werewolf
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : vote
#   target : [1, 2, 5]
#   description : 狼人投票殺人
#
# True
# 3-0-seer
#   user : [0]
#   operation : vote
#   target : []
#   description : 預言家查身分
#
# 3-0-witch
#   user : [1]
#   operation : vote_or_not
#   target : [1, 5]
#   description : 女巫毒人
#
# True
# 3-1-check_end1
#   user : [1]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [5]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=7 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=7 , chat="" , room_name=room_name , stage_name="1-0-seer"))
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))

    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    #### 1投4(救人) ####
    #print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=4 , chat="save" , room_name=room_name , stage_name="1-0-witch"))
    #print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=6 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false

    ### 4 死 ###
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-check_end1"))
    print(sendUserOperation(stub , user=4 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="1-1-check_end1"))
    #### 第一天發言 ####

    for _ in range(6):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        for i in range(6): 
            print(sendUserOperation(stub , user=i , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 0,1,2,3,4,5,6 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))
    #### 0,1,2,3投6 4,5,6投3 ####
    for i in range(7):
        target = 6 if i<4 else 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print(sendUserOperation(stub , user=0, operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=6 , chat="" , room_name=room_name , stage_name="1-1-vote1"))


    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))

    ### 獵人stage
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-hunter2"))
    
    #### 第一天6獵人死掉發言及發動技能 ####
    #### 0,1,2,3,4,5 存活 ####
    print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    
    print(sendUserOperation(stub , user=6 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="1-1-hunter2"))
    ####################

    #### 第一天4被獵人殺掉發言 ####
    #### 0,1,2,3,5 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    
    #### 第二天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    #### 5投0 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=0 , chat="" , room_name=room_name , stage_name="2-0-werewolf"))

    #### 第二天預言家驗人 ####

    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-werewolf"))
    print(sendUserOperation(stub , user=0 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="2-0-seer"))
    print(sendUserOperation(stub , user=0 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="2-0-seer"))
    ####################

    #### 第二天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-seer"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=0, chat="save" , room_name=room_name , stage_name="2-0-witch"))
    #### 第二天公告誰死了 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    #### 1,2,3,5 存活 ####
    
    #### 第二天發言 ####
    for _ in range(5):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        for i in range(6): 
            print(sendUserOperation(stub , user=i , operation="dialogue" , target=5 , chat="hello" , room_name=room_name , stage_name="2-1-dialogue"))
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    # print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))

    
    #### 第二天投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))

    #### 1,2 投5 3,5投3 ####
    # for i in [1,2,3,5]:
    #     target = 5 if i<3 else 3
    #     print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="2-1-vote1"))
    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="2-1-vote1"))

    #### 第二天二次投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))

    #### 5投3 ####
    #print(sendUserOperation(stub , user=5 , operation="vote_or_not" , target=3 , chat="" , room_name=room_name , stage_name="2-1-vote2"))

    #### 第二天3死了發表遺言 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="2-1-check_end3"))
    print("##")
    #### 1,2,5 存活 ####
    
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    #### 第三天狼人投票 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=1, chat="" , room_name=room_name , stage_name="3-0-werewolf"))
    #### 5投1 ####
    

    #### 第三天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-check_end3"))
    
    #### 第三天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-werewolf"))
    print("毒")
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=2 , chat="poison" , room_name=room_name , stage_name="3-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=0 , chat="save" , room_name=room_name , stage_name="3-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=3 , chat="save" , room_name=room_name , stage_name="3-0-witch"))
    #### 遊戲結束 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

    # dialogue
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))


    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=3 , chat="poison" , room_name=room_name , stage_name="4-0-witch"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=-1 , chat="poison" , room_name=room_name , stage_name="4-0-witch"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

if __name__ == '__main__':
    logging.basicConfig()
    run()
# Out:
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# False
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# False
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 是好人
#
#   user : [1]
#   operation : vote_or_not
#   target : [4]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# 1-1-check_end1
#   user : [4]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
# True
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description : 12345
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# True
# False
# False
# False
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# True
# False
# False
# 1-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# False
# False
# True
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# False
# False
# False
# 1-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# True
# False
# False
# False
# False
# False
# 1-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# True
# False
# False
# False
# False
# 1-1-vote1
#   user : [1]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [0, 1, 2, 3, 5, 6]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5, 6]
#   description : 投票階段
#
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# vote info :  [-1, 6, 6, 6, -1, 3, 3]
# 1-1-hunter2
#   user : [6]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : [6]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 獵人殺人
#
# True
# True
# 1-1-check_end3
#   user : [6]
#   operation : chat
#   target : []
#   description : 12345
#
# 2-0-werewolf
#   user : [5]
#   operation : vote
#   target : [0, 1, 2, 3, 5]
#   description : 狼人投票殺人
#
# True
# 2-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 5]
#   description : 預言家查身分
#
# False
# True
# 2-0-witch
#   user : [0]
#   operation : role_info
#   target : [5]
#   description : 是壞人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 女巫毒人
#
# True
# 2-1-check_end1
#   user : []
#   operation : other
#   target : []
#   description : 昨晚是平安夜
#
# 2-1-dialogue
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# True
# False
# False
# False
# 2-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description : hello
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# True
# False
# False
# 2-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description : hello
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# False
# False
# False
# False
# True
# 2-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description : hello
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# True
# False
# False
# False
# False
# False
# 2-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description : hello
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# True
# False
# False
# False
# False
# 2-1-vote1
#   user : [1]
#   operation : chat
#   target : []
#   description : hello
#
#   user : [0, 1, 2, 3, 5]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 投票階段
#
# vote info :  [-1, -1, -1, -1, -1, -1, -1]
# 2-1-vote2
#   user : [0, 1, 2, 3, 5]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 投票階段
#
# 2-1-check_end3
#   user : []
#   operation : other
#   target : []
#   description : 沒人被投出去
#
# False
# ##
# 3-0-werewolf
#   user : [5]
#   operation : vote
#   target : [0, 1, 2, 3, 5]
#   description : 狼人投票殺人
#
# True
# 3-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 5]
#   description : 預言家查身分
#
# 3-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 是好人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 5]
#   description : 女巫毒人
#
# 毒
# True
# False
# False
# 3-1-check_end1
#   user : [1]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [2]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 3-1-dialogue
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 3-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 3-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 3-1-vote1
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [0, 3, 5]
#   operation : vote_or_not
#   target : [0, 3, 5]
#   description : 投票階段
#
# 3-1-vote2
#   user : [0, 3, 5]
#   operation : vote_or_not
#   target : [0, 3, 5]
#   description : 投票階段
#
# 3-1-check_end3
#   user : []
#   operation : other
#   target : []
#   description : 沒人被投出去
#
# 4-0-werewolf
#   user : [5]
#   operation : vote
#   target : [0, 3, 5]
#   description : 狼人投票殺人
#
# 4-0-seer
#   user : [0]
#   operation : vote
#   target : [5, 3]
#   description : 預言家查身分
#
# 4-0-witch
#   user : [0]
#   operation : role_info
#   target : [5]
#   description : 是壞人
#
# False
# False
# 4-1-check_end1
#   user : [3]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=4 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))

    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    #### 1投4(救人) ####
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=6 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=4 , chat="save" , room_name=room_name , stage_name="1-0-witch"))

    ### 平安夜 ###
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-check_end1"))

    #### 第一天發言 ####

    for _ in range(7):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        for i in range(7): 
            print(sendUserOperation(stub , user=i , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 0,1,2,3,4,5,6 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))
    #### 0,1,2,3投6 4,5,6投3 ####
    for i in range(7):
        target = 6 if i<4 else 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print(sendUserOperation(stub , user=0, operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))
    print(sendUserOperation(stub , user=1, operation="vote_or_not" , target=4 , chat="" , room_name=room_name , stage_name="1-1-vote1"))


    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))

    ### 獵人stage
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-hunter2"))
    
    #### 第一天6獵人死掉發言及發動技能 ####
    #### 0,1,2,3,4,5 存活 ####
    print(sendUserOperation(stub , user=6 , operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-hunter2"))
    
    print(sendUserOperation(stub , user=6 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="1-1-hunter2"))
    ####################

    #### 第一天4被獵人殺掉發言 ####
    #### 0,1,2,3,5 存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    
    #### 第二天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
    #### 5投0 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=0 , chat="" , room_name=room_name , stage_name="2-0-werewolf"))

    #### 第二天預言家驗人 ####

    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-werewolf"))
    ####################

    #### 第二天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-0-seer"))
    #### 第二天公告誰死了 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    #### 1,2,3,5 存活 ####
    
    #### 第二天發言 ####
    
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-dialogue"))

    
    #### 第二天投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))

    #### 1,2 投5 3,5投3 ####
    # for i in [1,2,3,5]:
    #     target = 5 if i<3 else 3
    #     print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="2-1-vote1"))
    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="2-1-vote1"))

    #### 第二天二次投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))

    #### 5投3 ####
    #print(sendUserOperation(stub , user=5 , operation="vote_or_not" , target=3 , chat="" , room_name=room_name , stage_name="2-1-vote2"))

    #### 第二天3死了發表遺言 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    print(sendUserOperation(stub , user=3 , operation="dialogue" , target=0 , chat="12345" , room_name=room_name , stage_name="2-1-check_end3"))
    print("##")
    #### 1,2,5 存活 ####
    
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-vote1"))
    #### 第三天狼人投票 ####
    print(sendUserOperation(stub , user=5 , operation="vote" , target=1, chat="" , room_name=room_name , stage_name="3-0-werewolf"))
    #### 5投1 ####
    

    #### 第三天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="2-1-check_end3"))
    
    #### 第三天女巫 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-werewolf"))
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=5 , chat="poison" , room_name=room_name , stage_name="3-0-witch"))
    
    #### 遊戲結束 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="3-0-seer"))

if __name__ == '__main__':
    logging.basicConfig()
    run()

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=0 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=0 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))

    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    #### 1投6(殺人) ####
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=6 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=4 , chat="save" , room_name=room_name , stage_name="1-0-witch"))

    ### 6毒殺 、0 狼殺 ###
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-check_end1"))

    print("發言")
    #### 第一天發言 ####
    # print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))

    for i in range(5):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        print(sendUserOperation(stub , user=5 , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 1,2,3,4,5存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))

    #### 1,2,3投2 4,5投3 ####
    for i in range(7):
        target = 2 if i<4 else 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))

    for i in [1,4,5]:
        target = 2 if i<4 else 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote2"))

    print(sendUserOperation(stub , user=2 , operation="vote_or_not" , target=4 , chat="" , room_name=room_name , stage_name="1-1-vote2"))
    print(sendUserOperation(stub , user=2 , operation="vote_or_not" , target=2 , chat="" , room_name=room_name , stage_name="1-1-vote2"))
    print(sendUserOperation(stub , user=5 , operation="vote_or_not" , target=-1 , chat="" , room_name=room_name , stage_name="1-1-vote2"))
    
    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))
    #### 第一天2被殺掉 ####
    #### 1,3,4,5 存活 ####
    #### 遊戲結束 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-check_end3"))
 

if __name__ == '__main__':
    logging.basicConfig()
    run()
# Out:
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 是好人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# False
# 1-1-check_end1
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
#   user : [6]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 發言
# 1-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# 1-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# True
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description : 123456
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# False
# 1-1-vote1
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [1, 2, 3, 4, 5]
#   operation : vote_or_not
#   target : [1, 2, 3, 4, 5]
#   description : 投票階段
#
# False
# True
# True
# True
# True
# True
# False
# True
# vote info :  [-1, -1, 2, 2, 3, 3, -1]
# 1-1-vote2
#   user : [1, 4, 5]
#   operation : vote_or_not
#   target : [2, 3]
#   description : 投票階段
#
# True
# True
# True
# False
# False
# True
# @
# vote info :  [-1, 2, -1, -1, 3, -1, -1]
# 1-1-check_end3
#   user : [3]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝

# %% [markdown]
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : []
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 1
#
#   user : [1]
#   operation : vote_or_not
#   target : [0]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# False
# 1-1-check_end1
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [0]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
#   user : [6]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 發言
# 1-1-dialogue
#   user : [0]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-vote1
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [1, 2, 3, 4, 5]
#   operation : vote_or_not
#   target : [1, 2, 3, 4, 5]
#   description : 投票階段
#
# True
# True
# True
# True
# True
# True
# True
# vote info :  [2, 2, 2, 2, 3, 3, 3]
# 1-1-check_end3
#   user : [2]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝

# %%
import logging

import grpc
import protobufs.werewolf_kill_pb2 as p_wkp
import protobufs.werewolf_kill_pb2_grpc as p_wkpg

import random

def checkRoleList(stub,role:list,room_name:str)->bool:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    return stub.checkRoleList(request=role_list).result

def startGame(stub,role:list,room_name:str)->tuple[list,str]:
    role_list  = p_wkp.roleList(role=role,room_name=room_name)
    assign_role_list = stub.startGame(request=role_list)
    return assign_role_list.role , assign_role_list.room_name

def nextStage(stub,room_name:str,stage_name:str)->tuple[list,str]:
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    stage_info = stub.nextStage(request=room_info)
    return stage_info.stage ,stage_info.stage_name

def sendUserOperation(stub,user:int,operation:str,target:int,chat:str,room_name:str,stage_name:str):

    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    user_operation = p_wkp.userOperation(user=user,operation=operation,target=target,chat=chat,room=room_info)
    return stub.sendUserOperation(request=user_operation).result

def voteInfo(stub,room_name:str,stage_name:str):
    room_info = p_wkp.roomInfo(room_name=room_name,stage_name=stage_name)
    return stub.voteInfo(request=room_info).state



def print_stage(grpc_return):
    stage , stage_name = grpc_return
    print(stage_name)
    for i in stage:
        print("  user :" , i.user)
        print("  operation :" , i.operation)
        print("  target :" , i.target)
        print("  description :" , i.description)
        print("")


def run():

    channel = grpc.insecure_channel('localhost:50051')
    stub = p_wkpg.werewolf_killStub(channel)

    room_name = "TESTROOM"
    
    #### checkRoleList test ####
    print(checkRoleList(stub,role=[1,1,2,2,1] , room_name=room_name)) # true
    print(checkRoleList(stub,role=[2,1,1,2,1] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,2,2] , room_name=room_name)) # false
    print(checkRoleList(stub,role=[1,1,1,3,1] , room_name=room_name)) # false
    ############################
    

    #### startGame test ####
    role , room_name = startGame(stub,role=[1,1,2,2,1] ,room_name=room_name)
    print("start_game : " , role) # [0,1,2,2,3,3,4]
    ############################

    #### 第一天狼人投票 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name=""))
    
    #### 4投4 5投4 ####
    print(sendUserOperation(stub , user=4 , operation="vote" , target=5 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=5 , operation="vote" , target=1 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))
    print(sendUserOperation(stub , user=4 , operation="vote" , target=1 , chat="" , room_name=room_name , stage_name="1-0-werewolf"))

    #### 第一天預言家驗人 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-werewolf"))
    #### 0投2 ####
    print(sendUserOperation(stub , user=0 , operation="vote" , target=2 , chat="" , room_name=room_name , stage_name="1-0-seer"))

    #### 第一天女巫 及 預言家結果 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-seer"))

    #### 1投6(殺人) ####
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=0 , chat="poison" , room_name=room_name , stage_name="1-0-witch")) # false
    print(sendUserOperation(stub , user=1 , operation="vote_or_not" , target=4 , chat="save" , room_name=room_name , stage_name="1-0-witch"))

    ### 6毒殺 、0 狼殺 ###
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-check_end1"))

    print("發言")
    #### 第一天發言 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))

    for i in range(4):
        print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-dialogue"))
        # print(sendUserOperation(stub , user=5 , operation="dialogue" , target=5 , chat="123456" , room_name=room_name , stage_name="1-1-dialogue"))
    
    #### 第一天投票 ####
    #### 1,2,3,4,5存活 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-0-vote1"))
    #### 1,2,3投2 4,5投3 ####
    for i in range(7):
        target = 6 if i<4 else 3
        print(sendUserOperation(stub , user=i , operation="vote_or_not" , target=target , chat="" , room_name=room_name , stage_name="1-1-vote1"))

    print("vote info : " , voteInfo(stub , room_name=room_name , stage_name="1-1-vote1"))

    #### 遊戲結束 ####
    print_stage(nextStage(stub,room_name=room_name , stage_name="1-1-hunter2"))
    
 

if __name__ == '__main__':
    logging.basicConfig()
    run()
# Out:
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 是好人
#
#   user : [1]
#   operation : vote_or_not
#   target : [1]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# False
# 1-1-check_end1
#   user : [1]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 發言
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-vote1
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [2, 3, 4, 5, 6]
#   operation : vote_or_not
#   target : [2, 3, 4, 5, 6]
#   description : 投票階段
#
# False
# False
# True
# True
# True
# True
# True
# vote info :  [-1, -1, 6, 6, 3, 3, 3]
# 1-1-check_end3
#   user : [3]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝

# %% [markdown]
# True
# False
# True
# False
# start_game :  [0, 1, 2, 2, 3, 3, 4]
# 1-0-werewolf
#   user : [4, 5]
#   operation : vote
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 狼人投票殺人
#
# True
# True
# True
# 1-0-seer
#   user : [0]
#   operation : vote
#   target : [1, 2, 3, 4, 5, 6]
#   description : 預言家查身分
#
# True
# 1-0-witch
#   user : [0]
#   operation : role_info
#   target : [2]
#   description : 1
#
#   user : [1]
#   operation : vote_or_not
#   target : [1]
#   description : 女巫救人
#
#   user : [1]
#   operation : vote_or_not
#   target : [0, 1, 2, 3, 4, 5, 6]
#   description : 女巫毒人
#
# True
# False
# 1-1-check_end1
#   user : [1]
#   operation : died
#   target : []
#   description : 昨晚死了
#
#   user : [1]
#   operation : dialogue
#   target : []
#   description : 說遺言
#
#   user : [0]
#   operation : died
#   target : []
#   description : 昨晚死了
#
# 發言
# 1-1-dialogue
#   user : [1]
#   operation : chat
#   target : []
#   description :
#
#   user : [4]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [4]
#   operation : chat
#   target : []
#   description :
#
#   user : [5]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [5]
#   operation : chat
#   target : []
#   description :
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [6]
#   operation : chat
#   target : []
#   description :
#
#   user : [2]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-dialogue
#   user : [2]
#   operation : chat
#   target : []
#   description :
#
#   user : [3]
#   operation : dialogue
#   target : []
#   description : 玩家發言
#
# 1-1-vote1
#   user : [3]
#   operation : chat
#   target : []
#   description :
#
#   user : [2, 3, 4, 5, 6]
#   operation : vote_or_not
#   target : [2, 3, 4, 5, 6]
#   description : 投票階段
#
# True
# True
# True
# True
# True
# True
# True
# vote info :  [6, 6, 6, 6, 3, 3, 3]
# 1-1-hunter2
#   user : [6]
#   operation : died
#   target : []
#   description : 被票出去了
#
#   user : [6]
#   operation : dialogue
#   target : []
#   description : 發遺言
#
#   user : [6]
#   operation : vote_or_not
#   target : [2, 3, 4, 5]
#   description : 獵人殺人
#
#   user : []
#   operation : end
#   target : []
#   description : 壞人陣營獲勝
